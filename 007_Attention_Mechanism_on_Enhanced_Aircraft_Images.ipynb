# %%
#clone YOLOv5 and
# !git clone https://github.com/akashAD98/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 11750, done.
# remote: Total 11750 (delta 0), reused 0 (delta 0), pack-reused 11750
# Receiving objects: 100% (11750/11750), 13.68 MiB | 23.16 MiB/s, done.
# Resolving deltas: 100% (7783/7783), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 40.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.8 MB/s eta 0:00:00
# ...
# Setup complete. Using torch 2.0.1+cu118 (CPU)

# %%
# !git clone https://github.com/PoojaPremnath2003/Enhanced_Images_Aircraft_YOLO
# Out:
# Cloning into 'Enhanced_Images_Aircraft_YOLO'...
# remote: Enumerating objects: 4808, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 4808 (delta 12), reused 27 (delta 11), pack-reused 4778
# Receiving objects: 100% (4808/4808), 6.04 GiB | 18.49 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# Updating files: 100% (9099/9099), done.

# %%
# !ls
# Out:
# benchmarks.py		       hubconf.py	 setup.cfg
# classify		       LICENSE		 train.py
# CONTRIBUTING.md		       models		 tutorial.ipynb
# data			       __pycache__	 utils
# detect.py		       README.md	 val.py
# Enhanced_Images_Aircraft_YOLO  requirements.txt
# export.py		       segment

# %%
import os
os.getcwd()
# Out:
# '/content/yolov5'

# %%
PATH="/content/yolov5/Enhanced_Images_Aircraft_YOLO"

# %%
# !python train.py --img 1024 --batch 16 --epochs 25 --data {PATH}/data.yaml --weights yolov5s.pt --cache --cfg /content/yolov5/models/yolov5s_CBAM.yaml
# Out:
# 2023-07-01 07:34:12.139573: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-01 07:34:12.194174: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-01 07:34:13.052821: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 1024 --conf 0.70 --source {PATH}/test/images
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=/content/yolov5/Enhanced_Images_Aircraft_YOLO/test/images, data=data/coco128.yaml, imgsz=[1024, 1024], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-215-gdf21b23 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# YOLOv5s_CBAM summary: 155 layers, 6356024 parameters, 0 gradients, 15.7 GFLOPs
# image 1/314 /content/yolov5/Enhanced_Images_Aircraft_YOLO/test/images/data10_112.png: 1024x1024 1 aircraft, 6.7ms
# image 2/314 /content/yolov5/Enhanced_Images_Aircraft_YOLO/test/images/data10_124.png: 1024x1024 1 aircraft, 7.4ms
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
